# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '../..'))
	print(os.getcwd())
except:
	pass

# %%
from collections import Counter
from data_science.vectors import distance, vector_subtract, scalar_multiply
from functools import reduce, partial
import math, random
from data_science.gradient_descent import *

# %%
# Оценка производной
derivative_estimate = partial(difference_quotient, square, h=0.00001)

# %%
def square(x):
    return x * x


def derivative(x):
    return 2 * x


import matplotlib.pyplot as plt
xs = range(-10, 10)
plt.title('Фактические производные и их оценки в сравнении')
plt.plot(xs, list(map(derivative, xs)), 'rx', label='Факт')
plt.plot(xs, list(map(derivative_estimate, xs)), 'b+', label='Оценка')
plt.legend(loc=9)
plt.show()

# %%
# Выбрать произвольную отправную точку
v = [random.randint(-10, 10) for i in range(3)]
tolerance = 0.0000001  # Константа точности расчета

while True:
    gradient = sum_of_squares_gradient(v)  # Вычислить градиент v
    next_v = step(v, gradient, -0.01)  # Сделать отрицательный шаг градиента
    if distance(next_v, v) < tolerance:  # остановиться при достижении приемлемого уровня, т.е. схождения
        break
    v = next_v  # продолжить если нет
